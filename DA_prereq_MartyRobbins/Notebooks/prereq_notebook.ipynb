# %%
print("Hello! Modify the Notebook")
# Out:
# Hello! Modify the Notebook

# %%
# My name is Marty Robbins, this is my Fourth Code:YOu course. I have taken Intro to 
# Programming, Google IT Support, Cybersecurity and now Data Analysis. I have worked 
# in coding and IT for 20 years previously, for the state of Kentucky. I am married 
# with 3 grown childrem and 8 grandchildrem. Not currently working, but hoping to find
# something very soon. Really excited to expand my knowledge base, I really like going
# to classes and learning.
